# %%
import pandas as pd

# %%
d = pd.read_csv("nass_crops.csv", sep='\t')
# Out:
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (18,21,22,25,29,35,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(d[(d.YEAR >= 2015) & (d.YEAR <= 2015)])
# Out:
# 0

# %%
d.rename(columns={'CV_%': 'CV'}, inplace=True)

# %%
d[['DOMAIN_DESC', 'COMMODITY_DESC', 'STATISTICCAT_DESC', 'AGG_LEVEL_DESC', 'COUNTRY_NAME', 'STATE_NAME' , 
   'COUNTY_NAME', 'UNIT_DESC', 'VALUE', 'YEAR']]
# Out:
#    DOMAIN_DESC            COMMODITY_DESC STATISTICCAT_DESC AGG_LEVEL_DESC  \
# 0        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 1        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 2        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 3        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 4        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 5        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 6        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 7        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 8        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 9        TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 10       TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# 11       TOTAL  FLOWERING PLANTS, POTTED             SALES          STATE
# ...
