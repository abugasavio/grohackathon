# %%
import pandas as pd
import numpy as np

# %%
d = pd.read_csv("nass_crops.csv", sep='\t', nrows=1000)

# %%
len(d[(d.YEAR >= 2014) & (d.YEAR <= 2014)])
# Out:
# 152

# %%
d.columns
# Out:
# Index([u'SOURCE_DESC', u'SECTOR_DESC', u'GROUP_DESC', u'COMMODITY_DESC',
#        u'CLASS_DESC', u'PRODN_PRACTICE_DESC', u'UTIL_PRACTICE_DESC',
#        u'STATISTICCAT_DESC', u'UNIT_DESC', u'SHORT_DESC', u'DOMAIN_DESC',
#        u'DOMAINCAT_DESC', u'AGG_LEVEL_DESC', u'STATE_ANSI', u'STATE_FIPS_CODE',
#        u'STATE_ALPHA', u'STATE_NAME', u'ASD_CODE', u'ASD_DESC', u'COUNTY_ANSI',
#        u'COUNTY_CODE', u'COUNTY_NAME', u'REGION_DESC', u'ZIP_5',
#        u'WATERSHED_CODE', u'WATERSHED_DESC', u'CONGR_DISTRICT_CODE',
#        u'COUNTRY_CODE', u'COUNTRY_NAME', u'LOCATION_DESC', u'YEAR',
#        u'FREQ_DESC', u'BEGIN_CODE', u'END_CODE', u'REFERENCE_PERIOD_DESC',
#        u'WEEK_ENDING', u'LOAD_TIME', u'VALUE', u'CV_%'],
#       dtype='object')

# %%
d.rename(columns={'CV_%': 'CV'}, inplace=True)

# %%
d = d[['DOMAIN_DESC', 'COMMODITY_DESC', 'GROUP_DESC', 'STATISTICCAT_DESC', 'AGG_LEVEL_DESC', 'COUNTRY_NAME', 'STATE_NAME' , 
   'COUNTY_NAME', 'UNIT_DESC', 'VALUE', 'YEAR']]

# %%
d.replace('(D)', np.NaN, inplace=True)
d
# Out:
#     DOMAIN_DESC            COMMODITY_DESC    GROUP_DESC STATISTICCAT_DESC  \
# 0         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 1         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 2         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 3         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 4         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 5         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 6         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 7         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 8         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 9         TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 10        TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# 11        TOTAL  FLOWERING PLANTS, POTTED  HORTICULTURE             SALES
# ...

# %%
len(d)
# Out:
# 1000

# %%
d.COMMODITY_DESC.value_counts()
# Out:
# BARLEY                      704
# FLOWERING PLANTS, POTTED    296
# Name: COMMODITY_DESC, dtype: int64

# %%
d['VALUE'] = d.VALUE.str.replace(',', '').astype(float)


d = d.sort_values('VALUE', ascending=False)

# %%
d[(d['AGG_LEVEL_DESC'] == 'COUNTY') & (d['COMMODITY_DESC'] == 'BARLEY')]
# Out:
#     DOMAIN_DESC COMMODITY_DESC   GROUP_DESC STATISTICCAT_DESC AGG_LEVEL_DESC  \
# 396       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 413       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 414       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 398       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 397       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 943       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 395       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 942       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 941       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 399       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 937       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# ...

# %%
# Highest barlery

county_name = dict(d2.sort_values('VALUE', ascending=False).iloc[0])['COUNTY_NAME']

barley_value = dict(d2.sort_values('VALUE', ascending=False).iloc[0])['VALUE']

barley_year = dict(d2.sort_values('VALUE', ascending=False).iloc[0])['YEAR']

"The highest barley production: BY " + county_name + " in the year " + str(barley_year) + " at " + str(barley_value) + " Acres"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-aa3fe6f723a1> in <module>()
#       1 # Highest barlery
#       2
# ----> 3 county_name = dict(d2.sort_values('VALUE', ascending=False).iloc[0])['COUNTY_NAME']
#       4
#       5 barley_value = dict(d2.sort_values('VALUE', ascending=False).iloc[0])['VALUE']
#
# NameError: name 'd2' is not defined

# %%
d3 = d[(d['AGG_LEVEL_DESC'] == 'NATIONAL') & (d['GROUP_DESC'] == 'HORTICULTURE')]

# %%
dict(d3.iloc[0])
# Out:
# {'AGG_LEVEL_DESC': 'NATIONAL',
#  'COMMODITY_DESC': 'FLOWERING PLANTS, POTTED',
#  'COUNTRY_NAME': 'UNITED STATES',
#  'COUNTY_NAME': nan,
#  'DOMAIN_DESC': 'TOTAL',
#  'GROUP_DESC': 'HORTICULTURE',
#  'STATE_NAME': 'US TOTAL',
#  'STATISTICCAT_DESC': 'SALES',
#  'UNIT_DESC': '$',
#  'VALUE': 1385123.0,
#  'YEAR': 2014}

# %%
d4 = d.groupby(['COMMODITY_DESC', 'YEAR'])

# %%
d4

for k, group in d4:
    print k
    print group
# Out:
# ('BARLEY', 1946)
#     DOMAIN_DESC COMMODITY_DESC   GROUP_DESC STATISTICCAT_DESC AGG_LEVEL_DESC  \
# 939       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 811       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 872       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# 769       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
#
#       COUNTRY_NAME  STATE_NAME COUNTY_NAME UNIT_DESC  VALUE  YEAR
# 939  UNITED STATES  CALIFORNIA    SISKIYOU     ACRES  39000  1946
# 811  UNITED STATES  CALIFORNIA   MENDOCINO     ACRES   2000  1946
# 872  UNITED STATES  CALIFORNIA      SHASTA     ACRES   1500  1946
# 769  UNITED STATES  CALIFORNIA    HUMBOLDT     ACRES    400  1946
# ('BARLEY', 1947)
#     DOMAIN_DESC COMMODITY_DESC   GROUP_DESC STATISTICCAT_DESC AGG_LEVEL_DESC  \
# 940       TOTAL         BARLEY  FIELD CROPS    AREA HARVESTED         COUNTY
# ...
