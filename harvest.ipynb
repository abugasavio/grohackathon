# %%
import pandas as pd

# %%
d = pd.read_csv("nass_crops.csv", sep='\t', nrows=100)

# %%
len(d[(d.YEAR >= 2009) & (d.YEAR <= 2014)])
# Out:
# 100

# %%
d.rename(columns={'CV_%': 'CV'}, inplace=True)

# %%
d
# Out:
#    SOURCE_DESC SECTOR_DESC    GROUP_DESC            COMMODITY_DESC  \
# 0       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 1       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 2       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 3       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 4       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 5       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 6       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 7       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 8       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 9       CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 10      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 11      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 12      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 13      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 14      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 15      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 16      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 17      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 18      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 19      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 20      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 21      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 22      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 23      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 24      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 25      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 26      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 27      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 28      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 29      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# ..         ...         ...           ...                       ...
# 70      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 71      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 72      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 73      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 74      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 75      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 76      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 77      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 78      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 79      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 80      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 81      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 82      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 83      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 84      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 85      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 86      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 87      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 88      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 89      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 90      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 91      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 92      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 93      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 94      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 95      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 96      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 97      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 98      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
# 99      CENSUS       CROPS  HORTICULTURE  FLOWERING PLANTS, POTTED
#
#                CLASS_DESC       PRODN_PRACTICE_DESC  \
# 0   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 1   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 2   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 3   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 4   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 5   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 6   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 7   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 8   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 9   INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 10  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 11  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 12  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 13  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 14  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 15  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 16  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 17  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 18  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 19  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 20  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 21  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 22  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 23  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 24  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 25  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 26  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 27  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 28  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 29  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# ..                    ...                       ...
# 70  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 71  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 72  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 73  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 74  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 75  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 76  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 77  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 78  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 79  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 80  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 81  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 82  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 83  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 84  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 85  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 86  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 87  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 88  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 89  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 90  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 91  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 92  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 93  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 94  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 95  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 96  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 97  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 98  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
# 99  INDOOR USE, HYDRANGEA  ALL PRODUCTION PRACTICES
#
#            UTIL_PRACTICE_DESC STATISTICCAT_DESC   UNIT_DESC  \
# 0                RETAIL, POTS             SALES        POTS
# 1                RETAIL, POTS             SALES        POTS
# 2                RETAIL, POTS             SALES        POTS
# 3                RETAIL, POTS             SALES        POTS
# 4                RETAIL, POTS             SALES        POTS
# 5                RETAIL, POTS             SALES        POTS
# 6                RETAIL, POTS             SALES        POTS
# 7                RETAIL, POTS             SALES        POTS
# 8                RETAIL, POTS             SALES        POTS
# 9                RETAIL, POTS             SALES        POTS
# 10               RETAIL, POTS             SALES        POTS
# 11               RETAIL, POTS             SALES        POTS
# 12               RETAIL, POTS             SALES        POTS
# 13               RETAIL, POTS             SALES        POTS
# 14               RETAIL, POTS             SALES        POTS
# 15               RETAIL, POTS             SALES        POTS
# 16               RETAIL, POTS             SALES        POTS
# 17               RETAIL, POTS             SALES        POTS
# 18               RETAIL, POTS             SALES        POTS
# 19               RETAIL, POTS             SALES        POTS
# 20               RETAIL, POTS             SALES        POTS
# 21               RETAIL, POTS             SALES        POTS
# 22               RETAIL, POTS             SALES        POTS
# 23               RETAIL, POTS             SALES        POTS
# 24               RETAIL, POTS             SALES        POTS
# 25               RETAIL, POTS             SALES        POTS
# 26               RETAIL, POTS             SALES        POTS
# 27               RETAIL, POTS             SALES        POTS
# 28               RETAIL, POTS             SALES        POTS
# 29               RETAIL, POTS             SALES        POTS
# ..                        ...               ...         ...
# 70               RETAIL, POTS             SALES        POTS
# 71               RETAIL, POTS             SALES        POTS
# 72               RETAIL, POTS             SALES        POTS
# 73               RETAIL, POTS             SALES        POTS
# 74               RETAIL, POTS             SALES        POTS
# 75               RETAIL, POTS             SALES        POTS
# 76  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 77  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 78  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 79  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 80  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 81  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 82  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 83  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 84  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 85  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 86  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 87  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 88  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 89  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 90  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 91  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 92  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 93  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 94  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 95  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 96  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 97  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 98  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
# 99  RETAIL, POTS, GE 5 INCHES             SALES  OPERATIONS
#
#                                            SHORT_DESC  ...   LOCATION_DESC  \
# 0   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         ALABAMA
# 1   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        ARKANSAS
# 2   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      CALIFORNIA
# 3   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      CALIFORNIA
# 4   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        COLORADO
# 5   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...     CONNECTICUT
# 6   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...     CONNECTICUT
# 7   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        DELAWARE
# 8   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         FLORIDA
# 9   FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         FLORIDA
# 10  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         GEORGIA
# 11  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         GEORGIA
# 12  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           IDAHO
# 13  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           IDAHO
# 14  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        ILLINOIS
# 15  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        ILLINOIS
# 16  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         INDIANA
# 17  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         INDIANA
# 18  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...            IOWA
# 19  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...            IOWA
# 20  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...          KANSAS
# 21  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        KENTUCKY
# 22  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        KENTUCKY
# 23  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       LOUISIANA
# 24  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       LOUISIANA
# 25  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           MAINE
# 26  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           MAINE
# 27  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        MARYLAND
# 28  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        MARYLAND
# 29  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...   MASSACHUSETTS
# ..                                                ...  ...             ...
# 70  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      WASHINGTON
# 71  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...   WEST VIRGINIA
# 72  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       WISCONSIN
# 73  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       WISCONSIN
# 74  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        US TOTAL
# 75  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        US TOTAL
# 76  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         ALABAMA
# 77  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        ARKANSAS
# 78  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      CALIFORNIA
# 79  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...      CALIFORNIA
# 80  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...     CONNECTICUT
# 81  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...     CONNECTICUT
# 82  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        DELAWARE
# 83  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         FLORIDA
# 84  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         FLORIDA
# 85  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         GEORGIA
# 86  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         GEORGIA
# 87  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           IDAHO
# 88  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           IDAHO
# 89  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        ILLINOIS
# 90  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        ILLINOIS
# 91  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         INDIANA
# 92  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...         INDIANA
# 93  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...            IOWA
# 94  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...            IOWA
# 95  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...        KENTUCKY
# 96  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       LOUISIANA
# 97  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...       LOUISIANA
# 98  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           MAINE
# 99  FLOWERING PLANTS, POTTED, INDOOR USE, HYDRANGE...  ...           MAINE
#
#     YEAR FREQ_DESC  BEGIN_CODE  END_CODE REFERENCE_PERIOD_DESC WEEK_ENDING  \
# 0   2009    ANNUAL           0         0                  YEAR         NaN
# 1   2014    ANNUAL           0         0                  YEAR         NaN
# 2   2009    ANNUAL           0         0                  YEAR         NaN
# 3   2014    ANNUAL           0         0                  YEAR         NaN
# 4   2014    ANNUAL           0         0                  YEAR         NaN
# 5   2009    ANNUAL           0         0                  YEAR         NaN
# 6   2014    ANNUAL           0         0                  YEAR         NaN
# 7   2014    ANNUAL           0         0                  YEAR         NaN
# 8   2009    ANNUAL           0         0                  YEAR         NaN
# 9   2014    ANNUAL           0         0                  YEAR         NaN
# 10  2009    ANNUAL           0         0                  YEAR         NaN
# 11  2014    ANNUAL           0         0                  YEAR         NaN
# 12  2009    ANNUAL           0         0                  YEAR         NaN
# 13  2014    ANNUAL           0         0                  YEAR         NaN
# 14  2009    ANNUAL           0         0                  YEAR         NaN
# 15  2014    ANNUAL           0         0                  YEAR         NaN
# 16  2009    ANNUAL           0         0                  YEAR         NaN
# 17  2014    ANNUAL           0         0                  YEAR         NaN
# 18  2009    ANNUAL           0         0                  YEAR         NaN
# 19  2014    ANNUAL           0         0                  YEAR         NaN
# 20  2009    ANNUAL           0         0                  YEAR         NaN
# 21  2009    ANNUAL           0         0                  YEAR         NaN
# 22  2014    ANNUAL           0         0                  YEAR         NaN
# 23  2009    ANNUAL           0         0                  YEAR         NaN
# 24  2014    ANNUAL           0         0                  YEAR         NaN
# 25  2009    ANNUAL           0         0                  YEAR         NaN
# 26  2014    ANNUAL           0         0                  YEAR         NaN
# 27  2009    ANNUAL           0         0                  YEAR         NaN
# 28  2014    ANNUAL           0         0                  YEAR         NaN
# 29  2009    ANNUAL           0         0                  YEAR         NaN
# ..   ...       ...         ...       ...                   ...         ...
# 70  2014    ANNUAL           0         0                  YEAR         NaN
# 71  2014    ANNUAL           0         0                  YEAR         NaN
# 72  2009    ANNUAL           0         0                  YEAR         NaN
# 73  2014    ANNUAL           0         0                  YEAR         NaN
# 74  2009    ANNUAL           0         0                  YEAR         NaN
# 75  2014    ANNUAL           0         0                  YEAR         NaN
# 76  2009    ANNUAL           0         0                  YEAR         NaN
# 77  2014    ANNUAL           0         0                  YEAR         NaN
# 78  2009    ANNUAL           0         0                  YEAR         NaN
# 79  2014    ANNUAL           0         0                  YEAR         NaN
# 80  2009    ANNUAL           0         0                  YEAR         NaN
# 81  2014    ANNUAL           0         0                  YEAR         NaN
# 82  2014    ANNUAL           0         0                  YEAR         NaN
# 83  2009    ANNUAL           0         0                  YEAR         NaN
# 84  2014    ANNUAL           0         0                  YEAR         NaN
# 85  2009    ANNUAL           0         0                  YEAR         NaN
# 86  2014    ANNUAL           0         0                  YEAR         NaN
# 87  2009    ANNUAL           0         0                  YEAR         NaN
# 88  2014    ANNUAL           0         0                  YEAR         NaN
# 89  2009    ANNUAL           0         0                  YEAR         NaN
# 90  2014    ANNUAL           0         0                  YEAR         NaN
# 91  2009    ANNUAL           0         0                  YEAR         NaN
# 92  2014    ANNUAL           0         0                  YEAR         NaN
# 93  2009    ANNUAL           0         0                  YEAR         NaN
# 94  2014    ANNUAL           0         0                  YEAR         NaN
# 95  2009    ANNUAL           0         0                  YEAR         NaN
# 96  2009    ANNUAL           0         0                  YEAR         NaN
# 97  2014    ANNUAL           0         0                  YEAR         NaN
# 98  2009    ANNUAL           0         0                  YEAR         NaN
# 99  2014    ANNUAL           0         0                  YEAR         NaN
#
#               LOAD_TIME    VALUE    CV
# 0   2015-01-31 00:00:00      820   NaN
# 1   2015-01-31 00:00:00      (D)   (D)
# 2   2015-01-31 00:00:00   10,922   NaN
# 3   2015-01-31 00:00:00      885   7.4
# 4   2015-01-31 00:00:00      (D)   (D)
# 5   2015-01-31 00:00:00      635   NaN
# 6   2015-01-31 00:00:00    1,368  72.6
# 7   2015-01-31 00:00:00      (D)   (D)
# 8   2015-01-31 00:00:00   10,103   NaN
# 9   2015-01-31 00:00:00      (D)   (D)
# 10  2015-01-31 00:00:00      (D)   NaN
# 11  2015-01-31 00:00:00      (D)   (D)
# 12  2015-01-31 00:00:00      (D)   NaN
# 13  2015-01-31 00:00:00      (D)   (D)
# 14  2015-01-31 00:00:00    1,380   NaN
# 15  2015-01-31 00:00:00      420   (L)
# 16  2015-01-31 00:00:00       92   NaN
# 17  2015-01-31 00:00:00    1,215  80.1
# 18  2015-01-31 00:00:00      (D)   NaN
# 19  2015-01-31 00:00:00      (D)   (D)
# 20  2015-01-31 00:00:00      (D)   NaN
# 21  2015-01-31 00:00:00      (D)   NaN
# 22  2015-01-31 00:00:00      (D)   (D)
# 23  2015-01-31 00:00:00      (D)   NaN
# 24  2015-01-31 00:00:00      (D)   (D)
# 25  2015-01-31 00:00:00      244   NaN
# 26  2015-01-31 00:00:00      (D)   (D)
# 27  2015-01-31 00:00:00    1,190   NaN
# 28  2015-01-31 00:00:00      (D)   (D)
# 29  2015-01-31 00:00:00    1,740   NaN
# ..                  ...      ...   ...
# 70  2015-01-31 00:00:00      (D)   (D)
# 71  2015-01-31 00:00:00      (D)   (D)
# 72  2015-01-31 00:00:00      (D)   NaN
# 73  2015-01-31 00:00:00      748  68.7
# 74  2015-01-31 00:00:00   63,722   NaN
# 75  2015-01-31 00:00:00  118,506  26.7
# 76  2015-01-31 00:00:00        3   NaN
# 77  2015-01-31 00:00:00        4  62.7
# 78  2015-01-31 00:00:00       15   NaN
# 79  2015-01-31 00:00:00        7  46.9
# 80  2015-01-31 00:00:00        3   NaN
# 81  2015-01-31 00:00:00        5  73.5
# 82  2015-01-31 00:00:00        2   (H)
# 83  2015-01-31 00:00:00       12   NaN
# 84  2015-01-31 00:00:00        3  77.5
# 85  2015-01-31 00:00:00        1   NaN
# 86  2015-01-31 00:00:00        2   (H)
# 87  2015-01-31 00:00:00        3   NaN
# 88  2015-01-31 00:00:00        1   (L)
# 89  2015-01-31 00:00:00       10   NaN
# 90  2015-01-31 00:00:00        4   (L)
# 91  2015-01-31 00:00:00        3   NaN
# 92  2015-01-31 00:00:00        3  89.4
# 93  2015-01-31 00:00:00        1   NaN
# 94  2015-01-31 00:00:00        2   (H)
# 95  2015-01-31 00:00:00        3   NaN
# 96  2015-01-31 00:00:00        1   NaN
# 97  2015-01-31 00:00:00        1   (H)
# 98  2015-01-31 00:00:00        5   NaN
# 99  2015-01-31 00:00:00        4  91.9
#
# [100 rows x 39 columns]
